# %% [markdown]
# # Survival Analysis on the MIMIC Dataset
#
# We consider a longitudinal clinical dataset extracted from the MIMIC database.
# Each patient is associated with several chronological medical reports collected during the follow-up period.
#
# The dataframe contains the following variables:
#
# - `'SUBJECT_ID'`: Unique identifier of a patient. A single patient may have several associated observations (clinical reports).
# - `'note_time'`: Datetime $t_j$ corresponding to the $j$-th clinical report of a patient.
# - `'embeddings'`:  Sentence embedding extracted from the clinical report. These embeddings are obtained using a biomedical NLP model followed by a SIF aggregation procedure applied to contextual word embeddings. Each embedding is represented as a vector in
#   $\mathbb{R}^p$, where typically $p = 768$.
# - `'delta_i'`: Event indicator associated with patient $i$. It's formally written as:
#   $$
#   \delta_i =
#   \begin{cases}
#   1 & \text{if the event is observed (death)}, \\
#   0 & \text{if the patient is censored.}
#   \end{cases}
#   $$
#
# - `'survival_time'` (or $T_i$): Observed survival time of patient $i$, expressed in days.
# - `'time_since_first_note'`: Relative time elapsed since the first available report of the patient.
# - `'death_time'`: Datetime of death if the event occurred. This variable is equal to `NaN` for censored patients.
#
# The objective is to transform the sequential trajectory of embeddings into meaningful covariates for survival analysis using the SigBERT pipeline:
# 1. temporal normalization,
# 2. path construction,
# 3. signature feature extraction,
# 4. Cox proportional hazards modeling.

# %%
import os
import sys
import time
import numpy as np
import pandas as pd
import skglm
from tqdm import tqdm

# %%
print("Jupyter is running on:", sys.executable)
# Out:
# Jupyter is running on: C:\Users\vivia\anaconda3\envs\sigbert\python.exe

# %%
# Add the src directory to the Python path
notebook_dir = os.path.dirname(os.path.abspath("__file__"))
src_path = os.path.abspath(os.path.join(notebook_dir, '.', 'src')) # ADAPT HERE
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# Now import our custom modules
from utils import *
from compression_pkg import *
from survival_analysis_sigbert import *
from metrics_plot_results_pkg import *

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install pandas numpy tqdm lifelines iisignature scikit-learn seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (2.2.6)
# Requirement already satisfied: tqdm in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (4.67.3)
# Requirement already satisfied: lifelines in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (0.30.0)
# Requirement already satisfied: iisignature in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (0.24)
# Requirement already satisfied: scikit-learn in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (1.7.2)
# Requirement already satisfied: seaborn in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (3.10.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: colorama in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from lifelines) (1.15.2)
# Requirement already satisfied: autograd>=1.5 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from lifelines) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from lifelines) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from lifelines) (1.2.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from formulaic>=0.2.2->lifelines) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from formulaic>=0.2.2->lifelines) (2.19.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from formulaic>=0.2.2->lifelines) (4.15.0)
# Requirement already satisfied: wrapt>=1.0 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from formulaic>=0.2.2->lifelines) (2.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\vivia\anaconda3\envs\sigbert\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## I) Data Importation

# %%
import pandas as pd
path_sub1 = r"C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_1.csv"

print("Testing Sub 1 read...")
df_sub1 = pd.read_csv(path_sub1)
print("Sub 1 read success! Shape:", df_sub1.shape)
# Out:
# Testing Sub 1 read...
# Sub 1 read success! Shape: (380, 11)

# %%
path_sub2 = r"C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_2.csv"
print("Testing Sub 2 read...")
df_sub2 = pd.read_csv(path_sub2)
print("Sub 2 read success! Shape:", df_sub2.shape)

print("Testing Concat...")
df_OG = pd.concat([df_sub1, df_sub2], axis=0, ignore_index=True)
print("Concat success! Total shape:", df_OG.shape)
# Out:
# Testing Sub 2 read...
# Sub 2 read success! Shape: (743, 11)
# Testing Concat...
# Concat success! Total shape: (1123, 11)

# %%
import os
import pandas as pd
import gc  # 垃圾回收機制

path_sub1 = r"C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_1.csv"
path_sub2 = r"C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_2.csv"

def load_and_optimize(path):
    print(f"Optimized loading: {path}")
    # 1. 先讀取前 2 行，看看有哪些欄位
    df_preview = pd.read_csv(path, nrows=2)
    
    # 2. 如果裡面有沉重的原始文字欄位（如 'TEXT', 'TEXT_CLEAN'），直接不讀它，節省記憶體
    cols_to_use = [c for c in df_preview.columns if c not in ['TEXT', 'TEXT_CLEAN']]
    
    # 3. 只讀取需要的核心欄位
    df = pd.read_csv(path, usecols=cols_to_use)
    return df

# 讀取並立刻釋放暫存
df_sub1 = load_and_optimize(path_sub1)
df_sub2 = load_and_optimize(path_sub2)

# 合併
df_OG = pd.concat([df_sub1, df_sub2], axis=0, ignore_index=True)
print(f"\n[SUCCESS] Lightweight df_OG created. Shape: {df_OG.shape}")

# 手動觸發記憶體清理
del df_sub1
del df_sub2
gc.collect()
# Out:
# Optimized loading: C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_1.csv
# Optimized loading: C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_2.csv
#
# [SUCCESS] Lightweight df_OG created. Shape: (1123, 10)
# 60

# %%
import sys
src_path = r"C:\Users\vivia\sigbert_mimic\src"
if src_path not in sys.path:
    sys.path.insert(0, src_path)

print("Testing import 1: utils")
from utils import *

print("Testing import 2: compression_pkg")
from compression_pkg import *

print("Testing import 3: metrics_plot_results_pkg")
from metrics_plot_results_pkg import *

print("Testing import 4: survival_analysis_pkg")
from survival_analysis_sigbert import *

print("[SUCCESS] All modules parsed without crashing!")
# Out:
# Testing import 1: utils
# Testing import 2: compression_pkg
# Testing import 3: metrics_plot_results_pkg
# Testing import 4: survival_analysis_pkg
# [SUCCESS] All modules parsed without crashing!

# %%
import os
import sys
import pandas as pd

# CRITICAL FIX FOR WINDOWS CRASH: Force matplotlib to render in the background (headless mode)
# This completely prevents the Jupyter kernel from dying during plot generation.
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# =====================================================================
# 1. Environment Setup & Source Code Injection
# =====================================================================
# Direct absolute path targeting your specific source directory
src_path = r"C:\Users\vivia\sigbert_mimic\src"

if src_path not in sys.path:
    sys.path.insert(0, src_path)

print(f"[INFO] Custom src path added: {src_path}")

# Load custom modules aligned precisely with your actual local file names
try:
    from utils import *
    from compression_pkg import *
    from metrics_plot_results_pkg import *
    # CORRECTION: Aligned with your actual file 'survival_analysis_sigbert.py'
    from survival_analysis_sigbert import * 
    print("[SUCCESS] All custom packages (utils, compression, metrics, survival) imported successfully!")
except ModuleNotFoundError as e:
    print(f"[ERROR] Failed to import modules. Please verify the folder structure. Details: {e}")

# =====================================================================
# 2. Data Loading & Partition Concatenation
# =====================================================================
# Defining absolute file paths for the locally processed sub-chunks
path_sub1 = r"C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_1.csv"
path_sub2 = r"C:\Users\vivia\sigbert_mimic\data\part_01_sub\arora_results_part_1_sub_2.csv"
EXPORT_DIR = r"C:\Users\vivia\sigbert_mimic\data\part_01_sub"

print("\nLoading partitions from local drive...")
df_sub1 = pd.read_csv(path_sub1)
df_sub2 = pd.read_csv(path_sub2)

# Vertically concatenate sub_1 and sub_2 to build the complete df_OG dataframe
df_OG = pd.concat([df_sub1, df_sub2], axis=0, ignore_index=True)
print(f"[SUCCESS] Merged df_OG completed. Total shape: {df_OG.shape}")

# =====================================================================
# 3. Data Preprocessing & Exploratory Diagnostics
# =====================================================================
print("\nRunning dataset conversion and diagnostics...\n" + "="*50)

# Format chronological clinical timelines and datetime columns
df_OG = convert_date_columns(df_OG)

# Generate baseline characteristics and event statistics for survival data
print_dataset_statistics(df_OG, var_id='SUBJECT_ID', var_death='delta_i')
print("="*50)

# Plot the distribution of clinical reports per patient trajectory safely in the background
export_img_path = os.path.join(EXPORT_DIR, 'report_dist.png')
try:
    plot_report_distribution_per_patient(df_OG, export_path=export_img_path, var_id='SUBJECT_ID')
    print(f"[SUCCESS] Exported report distribution chart safely to: {export_img_path}")
except Exception as e:
    print(f"[WARNING] Plotting function encountered a rendering warning: {e}")

print(f"\n[SUCCESS] Baseline Preprocessing Pipeline Completed!")
# Out:
# [INFO] Custom src path added: C:\Users\vivia\sigbert_mimic\src
# [SUCCESS] All custom packages (utils, compression, metrics, survival) imported successfully!
#
# Loading partitions from local drive...
# [SUCCESS] Merged df_OG completed. Total shape: (1123, 11)
#
# Running dataset conversion and diagnostics...
# ==================================================
# Total number of patients in the dataset: 30
# Total number of medical reports: 1123
# Average number of reports per patient: 37.43
# Number of deceased patients: 9
# Number of censored patients: 21
# ==================================================

# %%
df_OG = convert_date_columns(df_OG)

# %%
print_dataset_statistics(df_OG, var_id="SUBJECT_ID", var_death="delta_i")

# %%
#plot_report_distribution_per_patient(df_OG, var_id="SUBJECT_ID", export_path=None)

# %% [markdown]
# ## II) Survival Modeling
#
# ### II)1) Landmark modeling

# %%
k_comp = 25; max_reports = 221
L_chosen = 36; w_chosen = 12  # Adapt the landmark point and window size by yourself.

# Build the landmark cohort
df_L, patients_L, df_gamma_L = define_landmark_cohort(
    df_OG,
    landmark_months=L_chosen,
    window_months=w_chosen
)

# Count number of clinical reports in the window
df_counts = (
    df_L.groupby("ID")
        .size()
        .reset_index(name="n_reports")
)
mean_reports = df_counts["n_reports"].mean()
std_reports = df_counts["n_reports"].std(ddof=1)

# Train-test construction
df_train_new_OG, test_groups = make_train_test(df_L)

# PCA compression
_, R_comp = pca_compression(df_train_new_OG, k_comp, verbose=True)

df_all = df_L.copy()

# %%
lambda_list_RO = [0.5, 1, 7]#np.arange(0.1, 12.1, 0.1)

results_summary_RO = []
global_lambda_results_RO = {}

start_global_RO = time.time()

for lambda_l1_CV_RO in tqdm(lambda_list_RO):

    print("\n===================================")
    print(f"Running Reports Only for lambda = {lambda_l1_CV_RO}")
    print("===================================")

    start = time.time()

    (
        df_results_RO,
        cph_RO,
        df_survival_RO,
        w_sk_RO,
        scores_RO,
        X_RO,
        y_train_RO,
        y_cox_RO,
        c_index_train_RO,
        c_index_test_list_RO,
        c_index_test_mean_RO,
        c_index_test_std_RO,
        df_survival_test_list_RO
    ) = global_sigbert_mimic_pipeline(
        df_full=df_all,
        df_train=df_train_new_OG,
        test_sets=test_groups,
        projection_matrix=R_comp,
        lambda_l1=lambda_l1_CV_RO,
        signature_order=2,
        use_levy_area=False,
        print_progress=False,
        use_standard_scaling=False
    )

# %%
# --------------------------------------------------
# Number of non-zero Cox coefficients
# --------------------------------------------------
non_zero_coefficients_RO = int(
    (w_sk_RO != 0).sum()
)

# --------------------------------------------------
# Confidence interval on test C-index
# --------------------------------------------------
lower_bound_RO, upper_bound_RO = (
    jackknife_confidence_interval(
        c_index_test_list_RO
    )
)

# --------------------------------------------------
# Execution time (minutes)
# --------------------------------------------------
execution_time_minutes = (
    time.time() - start
) / 60

# --------------------------------------------------
# Store model results
# --------------------------------------------------
global_lambda_results_RO[lambda_l1_CV_RO] = {
    "model": cph_RO,
    "cox_coefficients": w_sk_RO,
    "c_index_train": c_index_train_RO,
    "c_index_test_mean": c_index_test_mean_RO,
    "c_index_test_std": c_index_test_std_RO,
    "non_zero_coefficients": non_zero_coefficients_RO,
    "execution_time_minutes": execution_time_minutes
}

# --------------------------------------------------
# Append summary results
# --------------------------------------------------
results_summary_RO.append({
    "lambda": lambda_l1_CV_RO,
    "C-index Train": np.round(
        c_index_train_RO,
        3
    ),
    "Mean C-index Test": np.round(
        c_index_test_mean_RO,
        3
    ),
    "C-index Test Std": np.round(
        c_index_test_std_RO,
        3
    ),
    "C-index CI95%": (
        f"[{lower_bound_RO:.4f}, "
        f"{upper_bound_RO:.4f}]"
    ),
    "Non-zero Coefficients": (
        non_zero_coefficients_RO
    ),
    "Execution Time (min)": np.round(
        execution_time_minutes,
        2
    )
})

# --------------------------------------------------
# Global results dataframe
# --------------------------------------------------
df_results_RO = pd.DataFrame(
    results_summary_RO
)

# --------------------------------------------------
# Select best lambda
# --------------------------------------------------
best_row_RO = df_results_RO.loc[
    df_results_RO[
        "Mean C-index Test"
    ].idxmax()
]

best_lambda_RO = best_row_RO["lambda"]

print("\n===================================")
print(
    f"Best lambda (Reports Only): "
    f"{best_lambda_RO}"
)
print("===================================")

print(best_row_RO)
